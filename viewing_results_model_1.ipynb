# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = "albert_blank_best_output.tsv"
f = open("best_output/%s" % (file), encoding="utf8")

df_actual_data = {
    "context": [],
    "question": [],
    "pred_answer": [],
    "label": [],
    "pred_verify": []
}

for idx, line in enumerate(f):
    if idx == 0:
        continue
        
    ts = line.split("\t")
    if len(ts) != 5:
        continue
        
    df_actual_data["context"].append(ts[0])
    df_actual_data["question"].append(ts[1])
    df_actual_data["pred_answer"].append(ts[2])
    df_actual_data["label"].append(int(ts[3][0]))
    df_actual_data["pred_verify"].append(int(ts[4][0]))
    
df_albert_blank = pd.DataFrame(df_actual_data)
df_albert_blank
# Out:
#                                                 context  \
# 0     In Marxian analysis, capitalist firms increasi...
# 1      With Harper's vision in mind, the University ...
# 2     Montpellier was among the most important of th...
# 3     None of the original treaties establishing the...
# 4      Colonialism is seen to be the architect decid...
# ...                                                 ...
# 3741   When such oxygen sinks became saturated, free...
# 3742   The investigation of the pathogen that caused...
# 3743   In 2011, the Mines ParisTech : Professional R...
# 3744   The Hawaiian Islands, for example, consist al...
# 3745   Most of these districts are located in Northe...
#
#                                                question  \
# 0     What do capitalist firms substitute equipment ...
# 1     In what year did the U of C become one of 7 fo...
# 2     What were the towns granted to the Huguenots i...
# 3     How many original treaties establishing the EU...
# ...

# %%
file = "albert_noans_best_output.tsv"
f = open("best_output/%s" % (file), encoding="utf8")

df_actual_data = {
    "context": [],
    "question": [],
    "pred_answer": [],
    "label": [],
    "pred_verify": []
}

for idx, line in enumerate(f):
    if idx == 0:
        continue
        
    ts = line.split("\t")
    if len(ts) != 5:
        continue
        
    df_actual_data["context"].append(ts[0])
    df_actual_data["question"].append(ts[1])
    df_actual_data["pred_answer"].append(ts[2])
    df_actual_data["label"].append(int(ts[3][0]))
    df_actual_data["pred_verify"].append(int(ts[4][0]))
    
df_albert_noans = pd.DataFrame(df_actual_data)
df_albert_noans
# Out:
#                                                 context  \
# 0      If T(n) is a polynomial in n, then the algori...
# 1      Despite that the Warsaw University of Technol...
# 2      In 2008, the University of Chicago announced ...
# 3     Commissioners have various privileges, such as...
# 4      Martin Parry, a climate expert who had been c...
# ...                                                 ...
# 3741   Culturally, Melbourne is home to a number of ...
# 3742   The procedure continues until the building is...
# 3743   If this necessary condition is satisfied, Dir...
# 3744   In 1976, BankAmericard was renamed and spun o...
# 3745   If they enter less dense brackish water, the ...
#
#                                                question  \
# 0     Assuming that T represents a polynomial in T(n...
# 1     What building is the most interesting of the l...
# 2     When were plans for the Harris Friedman Instit...
# 3     Who did not have immunity from prosecution for...
# ...

# %%
file = "roberta_blank_best_output.tsv"
f = open("best_output/%s" % (file), encoding="utf8")

df_actual_data = {
    "context": [],
    "question": [],
    "pred_answer": [],
    "label": [],
    "pred_verify": []
}

for idx, line in enumerate(f):
    if idx == 0:
        continue
        
    ts = line.split("\t")
    if len(ts) != 5:
        continue
        
    df_actual_data["context"].append(ts[0])
    df_actual_data["question"].append(ts[1])
    df_actual_data["pred_answer"].append(ts[2])
    df_actual_data["label"].append(int(ts[3][0]))
    df_actual_data["pred_verify"].append(int(ts[4][0]))
    
df_roberta_blank = pd.DataFrame(df_actual_data)
df_roberta_blank
# Out:
#                                                 context  \
# 0      If T(n) is a polynomial in n, then the algori...
# 1      Despite that the Warsaw University of Technol...
# 2      In 2008, the University of Chicago announced ...
# 3     Commissioners have various privileges, such as...
# 4      Martin Parry, a climate expert who had been c...
# ...                                                 ...
# 3741  The Daily Mail newspaper reported in 2012 that...
# 3742   However, since most antibiotics non-specifica...
# 3743  In the 1960s, a series of discoveries, the mos...
# 3744  The efficiency of a Rankine cycle is usually l...
# 3745   A small group of Huguenots also settled on th...
#
#                                                question  \
# 0     Assuming that T represents a polynomial in T(n...
# 1     What building is the most interesting of the l...
# 2     When were plans for the Harris Friedman Instit...
# 3     Who did not have immunity from prosecution for...
# ...

# %%
file = "roberta_noans_best_output.tsv"
f = open("best_output/%s" % (file), encoding="utf8")

df_actual_data = {
    "context": [],
    "question": [],
    "pred_answer": [],
    "label": [],
    "pred_verify": []
}

for idx, line in enumerate(f):
    if idx == 0:
        continue
        
    ts = line.split("\t")
    if len(ts) != 5:
        continue
        
    df_actual_data["context"].append(ts[0])
    df_actual_data["question"].append(ts[1])
    df_actual_data["pred_answer"].append(ts[2])
    df_actual_data["label"].append(int(ts[3][0]))
    df_actual_data["pred_verify"].append(int(ts[4][0]))
    
df_roberta_noans = pd.DataFrame(df_actual_data)
df_roberta_noans
# Out:
#                                                 context  \
# 0         1%) were made up of individuals and 12,344 (7
# 1     Other important complexity classes include BPP...
# 2      Ersatzschulen lack the freedom to operate com...
# 3     [citation needed] In 1705, Amsterdam and the a...
# 4      When the Interstate Highway System was create...
# ...                                                 ...
# 3742   In the late 19th century, the Yarrow-Schlick-...
# 3743   The wine industry in South Africa owes a sign...
# 3744  The availability of the Bible in vernacular la...
# 3745   The tax collector who arrested him rose to hi...
# 3746   Those MHC antigens are recognized by killer c...
#
#                                                question  \
# 0     How many households had someone alone under th...
# 1     What are the other four important complexity c...
# 2     What do Sonderungsverbot not have when trying ...
# 3      How many Huguenots lived in West Frisia in 1705?
# ...

# %%
import seaborn as sns

# %%
def confusion_values(df):
    labels = df["label"].values
    pred = df["pred_verify"].values
    
    # y axis is label
    # x axis is pred
    
    tp = 0
    fp = 0
    fn = 0
    tn = 0

    
    for i in range(len(labels)):
        cur_l = labels[i]
        cur_p = pred[i]
        
        if cur_l == cur_p:
            if cur_l == 1:
                tp += 1
            else:
                tn += 1
        else:
            if cur_l == 1:
                fn += 1
            else:
                fp += 1
    
    return np.array([[tp,fp], [fn,tn]])

# %%
def tpr_tnr(conf):
    tpr = conf[0][0] / (conf[0][0] + conf[1][0])
    tnr = conf[1][1] / (conf[0][1] + conf[1][1])
    return tpr, tnr

# %%
albert_blank_conf = confusion_values(df_albert_blank)
print("albert_blank_conf")
print(albert_blank_conf)
print(tpr_tnr(albert_blank_conf))
albert_noans_conf = confusion_values(df_albert_noans)
print("\nalbert_noans_conf")
print(albert_noans_conf)
print(tpr_tnr(albert_noans_conf))
roberta_noans_conf = confusion_values(df_roberta_blank)
print("\nroberta_noans_conf")
print(roberta_noans_conf)
print(tpr_tnr(roberta_noans_conf))
roberta_blank_conf = confusion_values(df_roberta_noans)
print("\nroberta_blank_conf")
print(roberta_blank_conf)
print(tpr_tnr(roberta_blank_conf))
# Out:
# albert_blank_conf
# [[1142 1097]
#  [ 724  783]]
# (0.6120042872454448, 0.41648936170212764)
#
# albert_noans_conf
# [[ 763  758]
#  [1103 1122]]
# (0.40889603429796356, 0.5968085106382979)
#
# roberta_noans_conf
# [[1030  990]
#  [ 835  891]]
# (0.5522788203753352, 0.47368421052631576)
#
# roberta_blank_conf
# [[ 733  754]
#  [1133 1127]]
# (0.3928188638799571, 0.5991493886230729)

# %%
def make_confusion_matrix(cf,
                          group_names=None,
                          categories='auto',
                          count=True,
                          percent=True,
                          cbar=True,
                          xyticks=True,
                          xyplotlabels=True,
                          sum_stats=True,
                          figsize=None,
                          cmap='Blues',
                          title=None):
    '''
    This function will make a pretty plot of an sklearn Confusion Matrix cm using a Seaborn heatmap visualization.
    Arguments
    ---------
    cf:            confusion matrix to be passed in
    group_names:   List of strings that represent the labels row by row to be shown in each square.
    categories:    List of strings containing the categories to be displayed on the x,y axis. Default is 'auto'
    count:         If True, show the raw number in the confusion matrix. Default is True.
    normalize:     If True, show the proportions for each category. Default is True.
    cbar:          If True, show the color bar. The cbar values are based off the values in the confusion matrix.
                   Default is True.
    xyticks:       If True, show x and y ticks. Default is True.
    xyplotlabels:  If True, show 'True Label' and 'Predicted Label' on the figure. Default is True.
    sum_stats:     If True, display summary statistics below the figure. Default is True.
    figsize:       Tuple representing the figure size. Default will be the matplotlib rcParams value.
    cmap:          Colormap of the values displayed from matplotlib.pyplot.cm. Default is 'Blues'
                   See http://matplotlib.org/examples/color/colormaps_reference.html
                   
    title:         Title for the heatmap. Default is None.
    '''


    # CODE TO GENERATE TEXT INSIDE EACH SQUARE
    blanks = ['' for i in range(cf.size)]

    if group_names and len(group_names)==cf.size:
        group_labels = ["{}\n".format(value) for value in group_names]
    else:
        group_labels = blanks

    if count:
        group_counts = ["{0:0.0f}\n".format(value) for value in cf.flatten()]
    else:
        group_counts = blanks

    if percent:
        group_percentages = ["{0:.2%}".format(value) for value in cf.flatten()/np.sum(cf)]
    else:
        group_percentages = blanks

    box_labels = [f"{v1}{v2}{v3}".strip() for v1, v2, v3 in zip(group_labels,group_counts,group_percentages)]
    box_labels = np.asarray(box_labels).reshape(cf.shape[0],cf.shape[1])


    # CODE TO GENERATE SUMMARY STATISTICS & TEXT FOR SUMMARY STATS
    if sum_stats:
        #Accuracy is sum of diagonal divided by total observations
        accuracy  = np.trace(cf) / float(np.sum(cf))

        #if it is a binary confusion matrix, show some more stats
        if len(cf)==2:
            #Metrics for Binary Confusion Matrices
            precision = cf[1,1] / sum(cf[:,1])
            recall    = cf[1,1] / sum(cf[1,:])
            f1_score  = 2*precision*recall / (precision + recall)
            stats_text = "\n\nAccuracy={:0.3f}\nPrecision={:0.3f}\nRecall={:0.3f}\nF1 Score={:0.3f}".format(
                accuracy,precision,recall,f1_score)
        else:
            stats_text = "\n\nAccuracy={:0.3f}".format(accuracy)
    else:
        stats_text = ""


    # SET FIGURE PARAMETERS ACCORDING TO OTHER ARGUMENTS
    if figsize==None:
        #Get default figure size if not set
        figsize = plt.rcParams.get('figure.figsize')

    if xyticks==False:
        #Do not show categories if xyticks is False
        categories=False


    # MAKE THE HEATMAP VISUALIZATION
    plt.figure(figsize=figsize)
    sns.heatmap(cf,annot=box_labels,fmt="",cmap=cmap,cbar=cbar,xticklabels=categories,yticklabels=categories)

    if xyplotlabels:
        plt.ylabel('True label')
        plt.xlabel('Predicted label' + stats_text)
    else:
        plt.xlabel(stats_text)
    
    if title:
        plt.title(title)

# %%
labels = ['True Pos','False Pos','False Neg','True Neg']
categories = ['Answerable', 'NonAnswerable']
make_confusion_matrix(albert_blank_conf, 
                      group_names=labels,
                      categories=categories)

# %%
labels = ['True Pos','False Pos','False Neg','True Neg']
categories = ['Answerable', 'NonAnswerable']
make_confusion_matrix(albert_noans_conf, 
                      group_names=labels,
                      categories=categories)

# %%
labels = ['True Pos','False Pos','False Neg','True Neg']
categories = ['Answerable', 'NonAnswerable']
make_confusion_matrix(roberta_blank_conf, 
                      group_names=labels,
                      categories=categories)

# %%
labels = ['True Pos','False Pos','False Neg','True Neg']
categories = ['Answerable', 'NonAnswerable']
make_confusion_matrix(roberta_noans_conf, 
                      group_names=labels,
                      categories=categories)
